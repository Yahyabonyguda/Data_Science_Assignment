# %%
# %pip install matplotlib
# Out:
# ...
#
# ...

# %%
import pandas as pd
# Out:
# C:\Users\YAHYA\AppData\Local\Temp\ipykernel_11752\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data
data = {
    'birth_month': ['January', 'JAN', 'Sept', 'january', 'July', 'September', 'April', 'January', 'November', 'December'],
    'state': [None, 'CA', 'Hawaii', 'AK', 'RI', 'California', 'CA', 'California', 'FL', 'Florida'],
    'pet': ['Cats', 'Cats', 'Dog', 'Dog', 'Cats', 'Cats', 'Dog', 'Cats', 'Dog', 'Cats']
}

# Create DataFrame
df = pd.DataFrame(data)

# Convert birth_month to title case
df['birth_month'] = df['birth_month'].str.title()

# Plot 1: Count of pets by birth month
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='birth_month', hue='pet')
plt.title('Count of Pets by Birth Month')
plt.xlabel('Birth Month')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Pet')
plt.tight_layout()
plt.show()

# Plot 2: Count of pets by state
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='state', hue='pet')
plt.title('Count of Pets by State')
plt.xlabel('State')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Pet')
plt.tight_layout()
plt.show()

# Plot 3: Count of pets by state (excluding NaN)
plt.figure(figsize=(10, 6))
sns.countplot(data=df.dropna(), x='state', hue='pet')
plt.title('Count of Pets by State (Excluding NaN)')
plt.xlabel('State')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Pet')
plt.tight_layout()
plt.show()
